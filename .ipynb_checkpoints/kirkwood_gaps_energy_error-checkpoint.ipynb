# %%
import numpy as np
import matplotlib.pyplot as plt
import scienceplots
plt.style.use(['science', 'notebook', 'grid'])

# %%
data = np.loadtxt("orbits_energy.txt")
t = data[:,0] / 365 / 100000
e = data[:,1]

# %%
plt.plot(t, e)
plt.show()
